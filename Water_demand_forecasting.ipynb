# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhan-crypto/AI-chatbot/blob/main/Water_demand_forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from datetime import datetime

# --- Configuration ---
TARGET_COL = 'Total_Consumption_L'
FORECAST_HORIZON = 24  # Forecasting next 24 hours

def load_and_preprocess_data(file_path):
    """Loads and merges historical water and weather data."""
    # Assuming the main data is an hourly time series
    df = pd.read_csv(file_path, parse_dates=['Timestamp'])
    df.set_index('Timestamp', inplace=True)

    # Placeholder: In a real project, you would merge weather and occupancy data here
    # Example: df = pd.merge(df, weather_df, left_index=True, right_index=True)

    return df

def create_time_features(df, include_lags=True):
    """Creates time-based features from the index."""
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek # 0=Monday, 6=Sunday
    df['month'] = df.index.month
    df['dayofyear'] = df.index.dayofyear
    df['weekofyear'] = df.index.isocalendar().week.astype(int)

    # Feature for "Is it a weekend/holiday?"
    df['is_weekend'] = df['dayofweek'].isin([5, 6]).astype(int)

    if include_lags:
        # **Crucial Feature for Water Demand: Lagged Consumption**
        # Demand is highly correlated with past demand (e.g., 24 hours ago, 7 days ago)
        df['lag_24hr'] = df[TARGET_COL].shift(24)
        df['lag_7day'] = df[TARGET_COL].shift(24*7)

        # Drop rows with NaN values created by the lag features
        df.dropna(inplace=True)

    return df

def train_xgboost_model(df):
    """Trains and evaluates the XGBoost Regressor model."""

    features = [col for col in df.columns if col not in [TARGET_COL]]

    X = df[features]
    y = df[TARGET_COL]

    # Use a time-series split (do not shuffle)
    train_size = int(len(df) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    print(f"Training on {len(X_train)} samples, testing on {len(X_test)} samples.")

    # Initialize and train the XGBoost Regressor
    # Hyperparameters tuned for a typical time-series task
    model = xgb.XGBRegressor(
        objective='reg:squarederror',
        n_estimators=1000,
        learning_rate=0.05,
        max_depth=6,
        subsample=0.7,
        colsample_bytree=0.7,
        random_state=42,
        n_jobs=-1
    )

    # Removed early stopping arguments due to version incompatibility
    model.fit(X_train, y_train,
              eval_set=[(X_test, y_test)])

    # --- Evaluation ---
    y_pred = model.predict(X_test)

    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)

    print("\n--- Model Performance ---")
    print(f"Root Mean Squared Error (RMSE): {rmse:.2f} L/hr")
    print(f"Mean Absolute Error (MAE): {mae:.2f} L/hr")

    return model, X_test.index[-1]

def make_future_forecast(model, last_timestamp, num_hours):
    """Generates the forecast for the next N hours."""

    print(f"\nGenerating forecast for the next {num_hours} hours...")

    future_index = pd.date_range(
        start=last_timestamp + pd.Timedelta(hours=1),
        periods=num_hours,
        freq='h'
    )

    # Create an empty DataFrame for future features
    future_df = pd.DataFrame(index=future_index)

    # Generate time features for the future period, excluding lags for now
    future_df = create_time_features(future_df.reset_index(names=['Timestamp']).set_index('Timestamp'), include_lags=False)

    # For a real forecast, you would need to:
    # 1. Fill in future weather forecasts (e.g., predicted T-max)
    # 2. Estimate future lagged consumption using the model's previous forecasts (recursive forecasting)
    # For this simple example, we fill lag features with the last known actual consumption
    # Ensure df is accessible or passed if needed, here it's a global variable from main
    global df # Access the df from the global scope

    last_actual_consumption = df[TARGET_COL].iloc[-1]
    last_week_consumption = df[TARGET_COL].iloc[-24*7]

    future_df['lag_24hr'] = last_actual_consumption
    future_df['lag_7day'] = last_week_consumption

    # Align features with the trained model's feature set
    # Exclude TARGET_COL as it's not present in future_df and shouldn't be a feature anyway
    # We also need to ensure that the features used for prediction match the training features.
    # For simplicity, let's assume all columns in future_df except TARGET_COL (if it existed) are features.
    # The train_xgboost_model already creates the 'features' list correctly.

    # Drop any remaining NaN values that might arise from manual lag creation if num_hours is too small
    future_df.dropna(inplace=True)

    # Now, filter future_df to only include features that the model was trained on
    # This assumes 'model' and its 'feature_names_in_' or similar are available.
    # A more robust solution would pass the feature list from train_xgboost_model
    # For this example, let's derive it from the training phase directly:
    training_features = [col for col in df.columns if col not in [TARGET_COL, 'lag_24hr', 'lag_7day']]
    # And add the explicitly created lag features
    training_features.extend(['lag_24hr', 'lag_7day'])

    # Ensure the order of columns matches the training data
    # This assumes create_time_features creates columns in a consistent order.
    # Re-running create_time_features on a dummy df to get the order might be needed for robustness
    # For now, let's assume `future_df` has all necessary columns due to manual assignment.

    # Temporarily create a dummy dataframe to get the feature order and check for missing columns
    dummy_df_for_features = create_time_features(pd.DataFrame(index=future_index.copy()), include_lags=False)
    dummy_df_for_features['lag_24hr'] = 0 # Placeholder
    dummy_df_for_features['lag_7day'] = 0 # Placeholder

    # Get the feature names used during training from the model itself
    # This is the most reliable way to ensure feature consistency
    expected_features = model.feature_names_in_ if hasattr(model, 'feature_names_in_') else list(X.columns) # X is not in scope here

    # A safer approach for this specific problem (KeyError from TARGET_COL in future_df) is simply
    # to ensure that create_time_features when used for future_df does NOT attempt to use TARGET_COL.
    # The original filtering for model.predict() was:
    # future_df = future_df[[col for col in future_df.columns if col != TARGET_COL]]
    # This line is not needed if TARGET_COL is never added to future_df in the first place.

    # Let's ensure feature_df has only the columns expected by the model in the correct order
    # This requires knowing the exact feature set from training. For now, we trust the manual creation.

    # The original issue was fixed by include_lags=False. The following block should ensure feature consistency.
    # Let's re-align the features of future_df with the features the model was trained on.
    # The 'features' variable from train_xgboost_model is not directly accessible here.
    # We need to ensure that `future_df` only contains the features used for training and in the correct order.

    # Assuming `features` from `train_xgboost_model` included the time features and the two lag features.
    # The simplest way to handle this without changing train_xgboost_model's return is to infer.
    # Let's re-run a small part of create_time_features to determine the features used during training.
    # This is a bit redundant but ensures correctness without refactoring train_xgboost_model's output.

    # Create a dummy row to get feature names in correct order
    dummy_row_for_feature_order = create_time_features(pd.DataFrame(index=[df.index[-1]], columns=[TARGET_COL]), include_lags=True)
    feature_names_in_order = dummy_row_for_feature_order.columns.drop(TARGET_COL).tolist()

    # Ensure future_df has all these columns, filling missing ones with 0 or a sensible default if they were part of training.
    # The `future_df` already has the necessary time features and lags were added manually.
    # We just need to ensure the order is correct and no extra columns are present.

    # Reorder future_df columns to match the training order
    final_future_df_features = []
    for feature in expected_features: # Use expected_features from model.feature_names_in_ or X.columns
        if feature in future_df.columns:
            final_future_df_features.append(feature)
        else:
            # Handle cases where a feature might not be dynamically created (e.g., external weather data)
            # For this example, we assume all features are either time-based or manually assigned lags.
            print(f"Warning: Feature '{feature}' from training is missing in future_df. Filling with 0.")
            future_df[feature] = 0 # Or a more appropriate default/imputation
            final_future_df_features.append(feature)

    future_df = future_df[final_future_df_features]

    # Make prediction
    forecast = model.predict(future_df)

    forecast_series = pd.Series(forecast, index=future_index, name='Forecast_L')
    print("Forecast (First 5 hours):")
    print(forecast_series.head())

    return forecast_series

# --- Main Execution ---
if __name__ == "__main__":
    # --- 1. Create Sample Data (Replace with your actual data path) ---
    # Create a dummy dataset resembling hourly water usage with a trend
    np.random.seed(42)
    timestamps = pd.date_range(start='2024-01-01', periods=8760, freq='h') # 1 year of hourly data
    daily_pattern = np.sin(np.linspace(0, 4*np.pi, 24)) * 500 + 2000 # Daily cycle
    noise = np.random.normal(0, 100, 8760)

    base_consumption = np.tile(daily_pattern, 365) + noise

    # Simulate a weekly/monthly increase and drop on holidays
    holiday_mask = (pd.Series(timestamps).dt.dayofweek >= 5).values
    consumption = base_consumption * (1 - 0.2 * holiday_mask) # 20% drop on weekends

    sample_data = pd.DataFrame({
        'Timestamp': timestamps,
        TARGET_COL: consumption.clip(min=100) # Min 100 L
    })
    sample_data.to_csv('sample_campus_water_data.csv', index=False)
    # -------------------------------------------------------------------

    # 1. Load & Preprocess
    df = load_and_preprocess_data('sample_campus_water_data.csv')
    df = create_time_features(df, include_lags=True)

    # 2. Train Model
    model, last_known_time = train_xgboost_model(df)

    # 3. Generate Forecast
    future_forecast = make_future_forecast(model, last_known_time, FORECAST_HORIZON)

    # 4. (Next Step) Pass 'future_forecast' to the Optimization Engine
    # This forecast is the input for the "optimal pumping schedule" generation.
# Out:
# Training on 6873 samples, testing on 1719 samples.
# [0]	validation_0-rmse:371.13841
# [1]	validation_0-rmse:354.96163
# [2]	validation_0-rmse:341.49406
# [3]	validation_0-rmse:326.74318
# [4]	validation_0-rmse:313.61235
# [5]	validation_0-rmse:300.50084
# [6]	validation_0-rmse:288.12324
# [7]	validation_0-rmse:276.69197
# [8]	validation_0-rmse:265.84706
# [9]	validation_0-rmse:255.36153
# [10]	validation_0-rmse:245.50059
# [11]	validation_0-rmse:236.36830
# [12]	validation_0-rmse:227.80341
# [13]	validation_0-rmse:219.63684
# [14]	validation_0-rmse:212.22769
# [15]	validation_0-rmse:205.02813
# [16]	validation_0-rmse:198.21447
# [17]	validation_0-rmse:192.17834
# [18]	validation_0-rmse:186.34182
# [19]	validation_0-rmse:180.29013
# [20]	validation_0-rmse:175.02253
# [21]	validation_0-rmse:170.29058
# [22]	validation_0-rmse:165.63899
# [23]	validation_0-rmse:161.26627
# [24]	validation_0-rmse:157.33026
# [25]	validation_0-rmse:153.59062
# [26]	validation_0-rmse:150.08750
# [27]	validation_0-rmse:146.90063
# [28]	validation_0-rmse:144.42155
# [29]	validation_0-rmse:141.94905
# [30]	validation_0-rmse:139.25920
# [31]	validation_0-rmse:136.81424
# [32]	validation_0-rmse:134.76854
# [33]	validation_0-rmse:133.14608
# [34]	validation_0-rmse:131.28691
# [35]	validation_0-rmse:129.43141
# [36]	validation_0-rmse:127.57450
# [37]	validation_0-rmse:125.82353
# [38]	validation_0-rmse:124.27895
# [39]	validation_0-rmse:122.97670
# [40]	validation_0-rmse:121.65446
# [41]	validation_0-rmse:120.39074
# [42]	validation_0-rmse:119.99681
# [43]	validation_0-rmse:118.92805
# [44]	validation_0-rmse:118.19450
# [45]	validation_0-rmse:117.25085
# [46]	validation_0-rmse:116.43977
# [47]	validation_0-rmse:115.47605
# [48]	validation_0-rmse:114.77454
# [49]	validation_0-rmse:114.06480
# [50]	validation_0-rmse:113.46228
# [51]	validation_0-rmse:112.91563
# [52]	validation_0-rmse:112.66447
# [53]	validation_0-rmse:112.21361
# [54]	validation_0-rmse:111.83989
# [55]	validation_0-rmse:111.39175
# [56]	validation_0-rmse:111.02728
# [57]	validation_0-rmse:110.74336
# [58]	validation_0-rmse:110.30088
# [59]	validation_0-rmse:109.88955
# [60]	validation_0-rmse:109.52738
# [61]	validation_0-rmse:109.40834
# [62]	validation_0-rmse:109.06767
# [63]	validation_0-rmse:108.78463
# [64]	validation_0-rmse:108.56170
# [65]	validation_0-rmse:108.30899
# [66]	validation_0-rmse:108.14366
# [67]	validation_0-rmse:108.05667
# [68]	validation_0-rmse:108.08298
# [69]	validation_0-rmse:108.05927
# [70]	validation_0-rmse:108.04350
# [71]	validation_0-rmse:108.04869
# [72]	validation_0-rmse:107.83883
# [73]	validation_0-rmse:107.69336
# [74]	validation_0-rmse:107.65454
# [75]	validation_0-rmse:107.63039
# [76]	validation_0-rmse:107.53548
# [77]	validation_0-rmse:107.63324
# [78]	validation_0-rmse:107.50290
# [79]	validation_0-rmse:107.37995
# [80]	validation_0-rmse:107.32226
# [81]	validation_0-rmse:107.30257
# [82]	validation_0-rmse:107.25007
# [83]	validation_0-rmse:107.12800
# [84]	validation_0-rmse:107.06360
# [85]	validation_0-rmse:106.99134
# [86]	validation_0-rmse:106.87505
# [87]	validation_0-rmse:106.77928
# [88]	validation_0-rmse:106.76642
# [89]	validation_0-rmse:106.84636
# [90]	validation_0-rmse:106.88028
# [91]	validation_0-rmse:106.75932
# [92]	validation_0-rmse:106.65663
# [93]	validation_0-rmse:106.65243
# [94]	validation_0-rmse:106.58278
# [95]	validation_0-rmse:106.53984
# [96]	validation_0-rmse:106.43859
# [97]	validation_0-rmse:106.43616
# [98]	validation_0-rmse:106.35743
# [99]	validation_0-rmse:106.36232
# [100]	validation_0-rmse:106.33420
# [101]	validation_0-rmse:106.36504
# [102]	validation_0-rmse:106.37447
# [103]	validation_0-rmse:106.42792
# [104]	validation_0-rmse:106.47639
# [105]	validation_0-rmse:106.47223
# [106]	validation_0-rmse:106.47829
# [107]	validation_0-rmse:106.49908
# [108]	validation_0-rmse:106.45201
# [109]	validation_0-rmse:106.40422
# [110]	validation_0-rmse:106.35765
# [111]	validation_0-rmse:106.34622
# [112]	validation_0-rmse:106.29248
# [113]	validation_0-rmse:106.31901
# [114]	validation_0-rmse:106.31136
# [115]	validation_0-rmse:106.36310
# [116]	validation_0-rmse:106.39173
# [117]	validation_0-rmse:106.31816
# [118]	validation_0-rmse:106.35106
# [119]	validation_0-rmse:106.31502
# [120]	validation_0-rmse:106.30989
# [121]	validation_0-rmse:106.31060
# [122]	validation_0-rmse:106.24558
# [123]	validation_0-rmse:106.24901
# [124]	validation_0-rmse:106.27704
# [125]	validation_0-rmse:106.27334
# [126]	validation_0-rmse:106.22544
# [127]	validation_0-rmse:106.26250
# [128]	validation_0-rmse:106.19211
# [129]	validation_0-rmse:106.13735
# [130]	validation_0-rmse:106.16465
# [131]	validation_0-rmse:106.18044
# [132]	validation_0-rmse:106.16746
# [133]	validation_0-rmse:106.17896
# [134]	validation_0-rmse:106.11903
# [135]	validation_0-rmse:106.09690
# [136]	validation_0-rmse:106.08122
# [137]	validation_0-rmse:106.07314
# [138]	validation_0-rmse:106.00256
# [139]	validation_0-rmse:106.04077
# [140]	validation_0-rmse:106.03373
# [141]	validation_0-rmse:106.03341
# [142]	validation_0-rmse:105.99826
# [143]	validation_0-rmse:105.97093
# [144]	validation_0-rmse:105.98430
# [145]	validation_0-rmse:105.97389
# [146]	validation_0-rmse:105.97211
# [147]	validation_0-rmse:106.00647
# [148]	validation_0-rmse:106.01968
# [149]	validation_0-rmse:106.00812
# [150]	validation_0-rmse:106.04840
# [151]	validation_0-rmse:105.97076
# [152]	validation_0-rmse:105.99277
# [153]	validation_0-rmse:105.97002
# [154]	validation_0-rmse:105.97594
# [155]	validation_0-rmse:105.96590
# [156]	validation_0-rmse:105.97071
# [157]	validation_0-rmse:105.99114
# [158]	validation_0-rmse:106.00152
# [159]	validation_0-rmse:106.02556
# [160]	validation_0-rmse:105.99639
# [161]	validation_0-rmse:106.00041
# [162]	validation_0-rmse:106.00807
# [163]	validation_0-rmse:106.06579
# [164]	validation_0-rmse:106.06369
# [165]	validation_0-rmse:106.06078
# [166]	validation_0-rmse:106.15513
# [167]	validation_0-rmse:106.20745
# [168]	validation_0-rmse:106.25118
# [169]	validation_0-rmse:106.25182
# [170]	validation_0-rmse:106.23054
# [171]	validation_0-rmse:106.21169
# [172]	validation_0-rmse:106.17372
# [173]	validation_0-rmse:106.24052
# [174]	validation_0-rmse:106.26095
# [175]	validation_0-rmse:106.21762
# [176]	validation_0-rmse:106.22788
# [177]	validation_0-rmse:106.24116
# [178]	validation_0-rmse:106.28146
# [179]	validation_0-rmse:106.27287
# [180]	validation_0-rmse:106.28187
# [181]	validation_0-rmse:106.30090
# [182]	validation_0-rmse:106.30333
# [183]	validation_0-rmse:106.27531
# [184]	validation_0-rmse:106.26918
# [185]	validation_0-rmse:106.27273
# [186]	validation_0-rmse:106.24959
# [187]	validation_0-rmse:106.28127
# [188]	validation_0-rmse:106.25115
# [189]	validation_0-rmse:106.36587
# [190]	validation_0-rmse:106.39372
# [191]	validation_0-rmse:106.40486
# [192]	validation_0-rmse:106.40369
# [193]	validation_0-rmse:106.38879
# [194]	validation_0-rmse:106.39436
# [195]	validation_0-rmse:106.35231
# [196]	validation_0-rmse:106.34536
# [197]	validation_0-rmse:106.38093
# [198]	validation_0-rmse:106.36825
# [199]	validation_0-rmse:106.31079
# [200]	validation_0-rmse:106.31691
# [201]	validation_0-rmse:106.31328
# [202]	validation_0-rmse:106.30694
# [203]	validation_0-rmse:106.25372
# [204]	validation_0-rmse:106.20578
# [205]	validation_0-rmse:106.25053
# [206]	validation_0-rmse:106.23162
# [207]	validation_0-rmse:106.27063
# [208]	validation_0-rmse:106.35881
# [209]	validation_0-rmse:106.36803
# [210]	validation_0-rmse:106.37354
# [211]	validation_0-rmse:106.37211
# [212]	validation_0-rmse:106.34641
# [213]	validation_0-rmse:106.40625
# [214]	validation_0-rmse:106.40024
# [215]	validation_0-rmse:106.43830
# [216]	validation_0-rmse:106.43358
# [217]	validation_0-rmse:106.40512
# [218]	validation_0-rmse:106.38283
# [219]	validation_0-rmse:106.39046
# [220]	validation_0-rmse:106.36178
# [221]	validation_0-rmse:106.33623
# [222]	validation_0-rmse:106.30049
# [223]	validation_0-rmse:106.27849
# [224]	validation_0-rmse:106.36314
# [225]	validation_0-rmse:106.33121
# [226]	validation_0-rmse:106.34399
# [227]	validation_0-rmse:106.39685
# [228]	validation_0-rmse:106.38913
# [229]	validation_0-rmse:106.40532
# [230]	validation_0-rmse:106.40112
# [231]	validation_0-rmse:106.41887
# [232]	validation_0-rmse:106.44298
# [233]	validation_0-rmse:106.43439
# [234]	validation_0-rmse:106.45570
# [235]	validation_0-rmse:106.47383
# [236]	validation_0-rmse:106.51552
# [237]	validation_0-rmse:106.50151
# [238]	validation_0-rmse:106.52281
# [239]	validation_0-rmse:106.66857
# [240]	validation_0-rmse:106.67540
# [241]	validation_0-rmse:106.65784
# [242]	validation_0-rmse:106.65667
# [243]	validation_0-rmse:106.73344
# [244]	validation_0-rmse:106.71821
# [245]	validation_0-rmse:106.74582
# [246]	validation_0-rmse:106.84651
# [247]	validation_0-rmse:106.91640
# [248]	validation_0-rmse:106.89254
# [249]	validation_0-rmse:106.87699
# [250]	validation_0-rmse:106.88687
# [251]	validation_0-rmse:106.91297
# [252]	validation_0-rmse:106.90772
# [253]	validation_0-rmse:106.89054
# [254]	validation_0-rmse:106.97324
# [255]	validation_0-rmse:106.97081
# [256]	validation_0-rmse:106.89975
# [257]	validation_0-rmse:106.93174
# [258]	validation_0-rmse:106.92847
# [259]	validation_0-rmse:106.95003
# [260]	validation_0-rmse:106.95879
# [261]	validation_0-rmse:106.96051
# [262]	validation_0-rmse:106.96984
# [263]	validation_0-rmse:106.99488
# [264]	validation_0-rmse:107.00837
# [265]	validation_0-rmse:106.97420
# [266]	validation_0-rmse:106.97154
# [267]	validation_0-rmse:107.01731
# [268]	validation_0-rmse:107.02396
# [269]	validation_0-rmse:107.07441
# [270]	validation_0-rmse:107.11633
# [271]	validation_0-rmse:107.09901
# [272]	validation_0-rmse:107.09009
# [273]	validation_0-rmse:107.17881
# [274]	validation_0-rmse:107.18282
# [275]	validation_0-rmse:107.19304
# [276]	validation_0-rmse:107.30616
# [277]	validation_0-rmse:107.27536
# [278]	validation_0-rmse:107.26315
# [279]	validation_0-rmse:107.27731
# [280]	validation_0-rmse:107.33180
# [281]	validation_0-rmse:107.34095
# [282]	validation_0-rmse:107.35332
# [283]	validation_0-rmse:107.33589
# [284]	validation_0-rmse:107.34690
# [285]	validation_0-rmse:107.32751
# [286]	validation_0-rmse:107.43922
# [287]	validation_0-rmse:107.44028
# [288]	validation_0-rmse:107.43820
# [289]	validation_0-rmse:107.47106
# [290]	validation_0-rmse:107.46348
# [291]	validation_0-rmse:107.46076
# [292]	validation_0-rmse:107.46349
# [293]	validation_0-rmse:107.44689
# [294]	validation_0-rmse:107.39312
# [295]	validation_0-rmse:107.34430
# [296]	validation_0-rmse:107.39079
# [297]	validation_0-rmse:107.35903
# [298]	validation_0-rmse:107.34201
# [299]	validation_0-rmse:107.32032
# [300]	validation_0-rmse:107.34250
# [301]	validation_0-rmse:107.30651
# [302]	validation_0-rmse:107.29266
# [303]	validation_0-rmse:107.28630
# [304]	validation_0-rmse:107.29118
# [305]	validation_0-rmse:107.31375
# [306]	validation_0-rmse:107.32721
# [307]	validation_0-rmse:107.32451
# [308]	validation_0-rmse:107.34235
# [309]	validation_0-rmse:107.33559
# [310]	validation_0-rmse:107.32852
# [311]	validation_0-rmse:107.27199
# [312]	validation_0-rmse:107.28067
# [313]	validation_0-rmse:107.21750
# [314]	validation_0-rmse:107.20977
# [315]	validation_0-rmse:107.23118
# [316]	validation_0-rmse:107.21904
# [317]	validation_0-rmse:107.27520
# [318]	validation_0-rmse:107.31715
# [319]	validation_0-rmse:107.31667
# [320]	validation_0-rmse:107.30926
# [321]	validation_0-rmse:107.42178
# [322]	validation_0-rmse:107.41940
# [323]	validation_0-rmse:107.39864
# [324]	validation_0-rmse:107.40293
# [325]	validation_0-rmse:107.40490
# [326]	validation_0-rmse:107.40005
# [327]	validation_0-rmse:107.40973
# [328]	validation_0-rmse:107.41223
# [329]	validation_0-rmse:107.44165
# [330]	validation_0-rmse:107.44864
# [331]	validation_0-rmse:107.42775
# [332]	validation_0-rmse:107.34514
# [333]	validation_0-rmse:107.32990
# [334]	validation_0-rmse:107.31179
# [335]	validation_0-rmse:107.33465
# [336]	validation_0-rmse:107.31518
# [337]	validation_0-rmse:107.31126
# [338]	validation_0-rmse:107.30054
# [339]	validation_0-rmse:107.28161
# [340]	validation_0-rmse:107.33770
# [341]	validation_0-rmse:107.33065
# [342]	validation_0-rmse:107.31514
# [343]	validation_0-rmse:107.30126
# [344]	validation_0-rmse:107.29274
# [345]	validation_0-rmse:107.31182
# [346]	validation_0-rmse:107.30583
# [347]	validation_0-rmse:107.32779
# [348]	validation_0-rmse:107.28973
# [349]	validation_0-rmse:107.28137
# [350]	validation_0-rmse:107.33488
# [351]	validation_0-rmse:107.32105
# [352]	validation_0-rmse:107.40620
# [353]	validation_0-rmse:107.43168
# [354]	validation_0-rmse:107.38541
# [355]	validation_0-rmse:107.43823
# [356]	validation_0-rmse:107.42247
# [357]	validation_0-rmse:107.44637
# [358]	validation_0-rmse:107.45579
# [359]	validation_0-rmse:107.45281
# [360]	validation_0-rmse:107.45944
# [361]	validation_0-rmse:107.52407
# [362]	validation_0-rmse:107.53781
# [363]	validation_0-rmse:107.52426
# [364]	validation_0-rmse:107.60513
# [365]	validation_0-rmse:107.62708
# [366]	validation_0-rmse:107.59848
# [367]	validation_0-rmse:107.60366
# [368]	validation_0-rmse:107.61668
# [369]	validation_0-rmse:107.60925
# [370]	validation_0-rmse:107.61253
# [371]	validation_0-rmse:107.59424
# [372]	validation_0-rmse:107.62144
# [373]	validation_0-rmse:107.58980
# [374]	validation_0-rmse:107.61434
# [375]	validation_0-rmse:107.55171
# [376]	validation_0-rmse:107.53095
# [377]	validation_0-rmse:107.53378
# [378]	validation_0-rmse:107.53048
# [379]	validation_0-rmse:107.51202
# [380]	validation_0-rmse:107.53462
# [381]	validation_0-rmse:107.53253
# [382]	validation_0-rmse:107.55454
# [383]	validation_0-rmse:107.55064
# [384]	validation_0-rmse:107.56805
# [385]	validation_0-rmse:107.61790
# [386]	validation_0-rmse:107.60658
# [387]	validation_0-rmse:107.63992
# [388]	validation_0-rmse:107.64818
# [389]	validation_0-rmse:107.63815
# [390]	validation_0-rmse:107.62170
# [391]	validation_0-rmse:107.63584
# [392]	validation_0-rmse:107.64322
# [393]	validation_0-rmse:107.64340
# [394]	validation_0-rmse:107.63345
# [395]	validation_0-rmse:107.62152
# [396]	validation_0-rmse:107.68879
# [397]	validation_0-rmse:107.68804
# [398]	validation_0-rmse:107.70188
# [399]	validation_0-rmse:107.69392
# [400]	validation_0-rmse:107.71243
# [401]	validation_0-rmse:107.74113
# [402]	validation_0-rmse:107.76281
# [403]	validation_0-rmse:107.80356
# [404]	validation_0-rmse:107.82201
# [405]	validation_0-rmse:107.81546
# [406]	validation_0-rmse:107.89895
# [407]	validation_0-rmse:107.90087
# [408]	validation_0-rmse:107.92981
# [409]	validation_0-rmse:107.92220
# [410]	validation_0-rmse:107.97413
# [411]	validation_0-rmse:108.00826
# [412]	validation_0-rmse:108.01139
# [413]	validation_0-rmse:108.02997
# [414]	validation_0-rmse:108.02672
# [415]	validation_0-rmse:108.03320
# [416]	validation_0-rmse:108.06792
# [417]	validation_0-rmse:108.08962
# [418]	validation_0-rmse:108.14450
# [419]	validation_0-rmse:108.17215
# [420]	validation_0-rmse:108.20015
# [421]	validation_0-rmse:108.17877
# [422]	validation_0-rmse:108.18643
# [423]	validation_0-rmse:108.18807
# [424]	validation_0-rmse:108.20580
# [425]	validation_0-rmse:108.20664
# [426]	validation_0-rmse:108.23746
# [427]	validation_0-rmse:108.22632
# [428]	validation_0-rmse:108.21387
# [429]	validation_0-rmse:108.21374
# [430]	validation_0-rmse:108.29857
# [431]	validation_0-rmse:108.27877
# [432]	validation_0-rmse:108.29996
# [433]	validation_0-rmse:108.26316
# [434]	validation_0-rmse:108.27159
# [435]	validation_0-rmse:108.26185
# [436]	validation_0-rmse:108.24899
# [437]	validation_0-rmse:108.24022
# [438]	validation_0-rmse:108.28663
# [439]	validation_0-rmse:108.27745
# [440]	validation_0-rmse:108.30911
# [441]	validation_0-rmse:108.31300
# [442]	validation_0-rmse:108.29287
# [443]	validation_0-rmse:108.28233
# [444]	validation_0-rmse:108.27157
# [445]	validation_0-rmse:108.28434
# [446]	validation_0-rmse:108.28551
# [447]	validation_0-rmse:108.30415
# [448]	validation_0-rmse:108.31007
# [449]	validation_0-rmse:108.34775
# [450]	validation_0-rmse:108.34252
# [451]	validation_0-rmse:108.33316
# [452]	validation_0-rmse:108.33093
# [453]	validation_0-rmse:108.29217
# [454]	validation_0-rmse:108.27031
# [455]	validation_0-rmse:108.31083
# [456]	validation_0-rmse:108.33645
# [457]	validation_0-rmse:108.34070
# [458]	validation_0-rmse:108.38346
# [459]	validation_0-rmse:108.39907
# [460]	validation_0-rmse:108.37769
# [461]	validation_0-rmse:108.47170
# [462]	validation_0-rmse:108.48431
# [463]	validation_0-rmse:108.46076
# [464]	validation_0-rmse:108.52049
# [465]	validation_0-rmse:108.53034
# [466]	validation_0-rmse:108.53243
# [467]	validation_0-rmse:108.53927
# [468]	validation_0-rmse:108.57466
# [469]	validation_0-rmse:108.58352
# [470]	validation_0-rmse:108.60164
# [471]	validation_0-rmse:108.64795
# [472]	validation_0-rmse:108.60405
# [473]	validation_0-rmse:108.60381
# [474]	validation_0-rmse:108.59083
# [475]	validation_0-rmse:108.60421
# [476]	validation_0-rmse:108.60723
# [477]	validation_0-rmse:108.59199
# [478]	validation_0-rmse:108.60357
# [479]	validation_0-rmse:108.63801
# [480]	validation_0-rmse:108.64684
# [481]	validation_0-rmse:108.69439
# [482]	validation_0-rmse:108.69845
# [483]	validation_0-rmse:108.79246
# [484]	validation_0-rmse:108.82913
# [485]	validation_0-rmse:108.81493
# [486]	validation_0-rmse:108.84963
# [487]	validation_0-rmse:108.84121
# [488]	validation_0-rmse:108.85748
# [489]	validation_0-rmse:108.85450
# [490]	validation_0-rmse:108.84107
# [491]	validation_0-rmse:108.87905
# [492]	validation_0-rmse:108.89864
# [493]	validation_0-rmse:108.87175
# [494]	validation_0-rmse:108.83505
# [495]	validation_0-rmse:108.82538
# [496]	validation_0-rmse:108.84535
# [497]	validation_0-rmse:108.87848
# [498]	validation_0-rmse:108.89025
# [499]	validation_0-rmse:108.87685
# [500]	validation_0-rmse:108.89387
# [501]	validation_0-rmse:108.90449
# [502]	validation_0-rmse:108.92321
# [503]	validation_0-rmse:108.91973
# [504]	validation_0-rmse:108.92690
# [505]	validation_0-rmse:108.92684
# [506]	validation_0-rmse:108.94586
# [507]	validation_0-rmse:108.89926
# [508]	validation_0-rmse:108.89564
# [509]	validation_0-rmse:108.88887
# [510]	validation_0-rmse:108.87408
# [511]	validation_0-rmse:108.88309
# [512]	validation_0-rmse:108.89946
# [513]	validation_0-rmse:108.90497
# [514]	validation_0-rmse:108.91981
# [515]	validation_0-rmse:108.90538
# [516]	validation_0-rmse:108.90515
# [517]	validation_0-rmse:108.90027
# [518]	validation_0-rmse:108.90306
# [519]	validation_0-rmse:108.89372
# [520]	validation_0-rmse:108.89814
# [521]	validation_0-rmse:108.84706
# [522]	validation_0-rmse:108.84317
# [523]	validation_0-rmse:108.84761
# [524]	validation_0-rmse:108.84655
# [525]	validation_0-rmse:108.86292
# [526]	validation_0-rmse:108.86919
# [527]	validation_0-rmse:108.86045
# [528]	validation_0-rmse:108.92848
# [529]	validation_0-rmse:108.91581
# [530]	validation_0-rmse:108.93113
# [531]	validation_0-rmse:108.91565
# [532]	validation_0-rmse:108.94175
# [533]	validation_0-rmse:108.94909
# [534]	validation_0-rmse:108.95340
# [535]	validation_0-rmse:108.95370
# [536]	validation_0-rmse:108.95579
# [537]	validation_0-rmse:108.97498
# [538]	validation_0-rmse:108.96513
# [539]	validation_0-rmse:108.94946
# [540]	validation_0-rmse:108.93199
# [541]	validation_0-rmse:108.95734
# [542]	validation_0-rmse:108.97425
# [543]	validation_0-rmse:108.99043
# [544]	validation_0-rmse:109.01457
# [545]	validation_0-rmse:109.00883
# [546]	validation_0-rmse:109.03243
# [547]	validation_0-rmse:109.02694
# [548]	validation_0-rmse:109.04685
# [549]	validation_0-rmse:109.02666
# [550]	validation_0-rmse:109.04606
# [551]	validation_0-rmse:109.03908
# [552]	validation_0-rmse:109.02716
# [553]	validation_0-rmse:109.05832
# [554]	validation_0-rmse:109.06379
# [555]	validation_0-rmse:109.13015
# [556]	validation_0-rmse:109.10854
# [557]	validation_0-rmse:109.10173
# [558]	validation_0-rmse:109.08903
# [559]	validation_0-rmse:109.03696
# [560]	validation_0-rmse:109.05434
# [561]	validation_0-rmse:109.07521
# [562]	validation_0-rmse:109.03476
# [563]	validation_0-rmse:109.05241
# [564]	validation_0-rmse:109.11627
# [565]	validation_0-rmse:109.11142
# [566]	validation_0-rmse:109.08688
# [567]	validation_0-rmse:109.08100
# [568]	validation_0-rmse:109.11048
# [569]	validation_0-rmse:109.13858
# [570]	validation_0-rmse:109.13792
# [571]	validation_0-rmse:109.27964
# [572]	validation_0-rmse:109.28568
# [573]	validation_0-rmse:109.28913
# [574]	validation_0-rmse:109.29174
# [575]	validation_0-rmse:109.30494
# [576]	validation_0-rmse:109.32756
# [577]	validation_0-rmse:109.35514
# [578]	validation_0-rmse:109.32321
# [579]	validation_0-rmse:109.32221
# [580]	validation_0-rmse:109.32543
# [581]	validation_0-rmse:109.31079
# [582]	validation_0-rmse:109.32254
# [583]	validation_0-rmse:109.30915
# [584]	validation_0-rmse:109.34870
# [585]	validation_0-rmse:109.35302
# [586]	validation_0-rmse:109.35609
# [587]	validation_0-rmse:109.33458
# [588]	validation_0-rmse:109.33916
# [589]	validation_0-rmse:109.31812
# [590]	validation_0-rmse:109.32219
# [591]	validation_0-rmse:109.26057
# [592]	validation_0-rmse:109.27127
# [593]	validation_0-rmse:109.31723
# [594]	validation_0-rmse:109.34756
# [595]	validation_0-rmse:109.33973
# [596]	validation_0-rmse:109.32117
# [597]	validation_0-rmse:109.30527
# [598]	validation_0-rmse:109.33308
# [599]	validation_0-rmse:109.36367
# [600]	validation_0-rmse:109.36744
# [601]	validation_0-rmse:109.34829
# [602]	validation_0-rmse:109.36000
# [603]	validation_0-rmse:109.34751
# [604]	validation_0-rmse:109.36514
# [605]	validation_0-rmse:109.37099
# [606]	validation_0-rmse:109.38304
# [607]	validation_0-rmse:109.42537
# [608]	validation_0-rmse:109.41218
# [609]	validation_0-rmse:109.40828
# [610]	validation_0-rmse:109.43009
# [611]	validation_0-rmse:109.51045
# [612]	validation_0-rmse:109.50074
# [613]	validation_0-rmse:109.48654
# [614]	validation_0-rmse:109.50450
# [615]	validation_0-rmse:109.50708
# [616]	validation_0-rmse:109.53302
# [617]	validation_0-rmse:109.55405
# [618]	validation_0-rmse:109.55784
# [619]	validation_0-rmse:109.54647
# [620]	validation_0-rmse:109.55472
# [621]	validation_0-rmse:109.55434
# [622]	validation_0-rmse:109.54726
# [623]	validation_0-rmse:109.53593
# [624]	validation_0-rmse:109.52155
# [625]	validation_0-rmse:109.53669
# [626]	validation_0-rmse:109.53253
# [627]	validation_0-rmse:109.51951
# [628]	validation_0-rmse:109.51711
# [629]	validation_0-rmse:109.53008
# [630]	validation_0-rmse:109.56929
# [631]	validation_0-rmse:109.55678
# [632]	validation_0-rmse:109.54585
# [633]	validation_0-rmse:109.53845
# [634]	validation_0-rmse:109.53857
# [635]	validation_0-rmse:109.54485
# [636]	validation_0-rmse:109.52428
# [637]	validation_0-rmse:109.53099
# [638]	validation_0-rmse:109.52669
# [639]	validation_0-rmse:109.50844
# [640]	validation_0-rmse:109.50415
# [641]	validation_0-rmse:109.50073
# [642]	validation_0-rmse:109.57826
# [643]	validation_0-rmse:109.58486
# [644]	validation_0-rmse:109.56427
# [645]	validation_0-rmse:109.55611
# [646]	validation_0-rmse:109.55475
# [647]	validation_0-rmse:109.53956
# [648]	validation_0-rmse:109.52186
# [649]	validation_0-rmse:109.53635
# [650]	validation_0-rmse:109.58429
# [651]	validation_0-rmse:109.58836
# [652]	validation_0-rmse:109.62826
# [653]	validation_0-rmse:109.62524
# [654]	validation_0-rmse:109.66132
# [655]	validation_0-rmse:109.64613
# [656]	validation_0-rmse:109.63960
# [657]	validation_0-rmse:109.64275
# [658]	validation_0-rmse:109.70478
# [659]	validation_0-rmse:109.70949
# [660]	validation_0-rmse:109.69550
# [661]	validation_0-rmse:109.69427
# [662]	validation_0-rmse:109.72147
# [663]	validation_0-rmse:109.72164
# [664]	validation_0-rmse:109.69976
# [665]	validation_0-rmse:109.73449
# [666]	validation_0-rmse:109.75252
# [667]	validation_0-rmse:109.75946
# [668]	validation_0-rmse:109.77745
# [669]	validation_0-rmse:109.77550
# [670]	validation_0-rmse:109.79726
# [671]	validation_0-rmse:109.78754
# [672]	validation_0-rmse:109.78569
# [673]	validation_0-rmse:109.74893
# [674]	validation_0-rmse:109.73417
# [675]	validation_0-rmse:109.73832
# [676]	validation_0-rmse:109.73800
# [677]	validation_0-rmse:109.75858
# [678]	validation_0-rmse:109.75215
# [679]	validation_0-rmse:109.74863
# [680]	validation_0-rmse:109.74107
# [681]	validation_0-rmse:109.71837
# [682]	validation_0-rmse:109.74998
# [683]	validation_0-rmse:109.73739
# [684]	validation_0-rmse:109.78575
# [685]	validation_0-rmse:109.75458
# [686]	validation_0-rmse:109.80290
# [687]	validation_0-rmse:109.81083
# [688]	validation_0-rmse:109.79192
# [689]	validation_0-rmse:109.79113
# [690]	validation_0-rmse:109.80818
# [691]	validation_0-rmse:109.78962
# [692]	validation_0-rmse:109.79496
# [693]	validation_0-rmse:109.81635
# [694]	validation_0-rmse:109.83060
# [695]	validation_0-rmse:109.83974
# [696]	validation_0-rmse:109.83538
# [697]	validation_0-rmse:109.90503
# [698]	validation_0-rmse:109.94779
# [699]	validation_0-rmse:109.93603
# [700]	validation_0-rmse:109.91521
# [701]	validation_0-rmse:109.90279
# [702]	validation_0-rmse:109.91239
# [703]	validation_0-rmse:109.94885
# [704]	validation_0-rmse:109.94940
# [705]	validation_0-rmse:109.92271
# [706]	validation_0-rmse:109.91752
# [707]	validation_0-rmse:109.94519
# [708]	validation_0-rmse:109.95976
# [709]	validation_0-rmse:109.93902
# [710]	validation_0-rmse:109.94037
# [711]	validation_0-rmse:109.96344
# [712]	validation_0-rmse:109.96952
# [713]	validation_0-rmse:109.99988
# [714]	validation_0-rmse:110.01645
# [715]	validation_0-rmse:110.00765
# [716]	validation_0-rmse:110.01230
# [717]	validation_0-rmse:110.00717
# [718]	validation_0-rmse:109.97320
# [719]	validation_0-rmse:109.98678
# [720]	validation_0-rmse:109.97964
# [721]	validation_0-rmse:109.94854
# [722]	validation_0-rmse:109.93411
# [723]	validation_0-rmse:109.91284
# [724]	validation_0-rmse:109.92119
# [725]	validation_0-rmse:109.92942
# [726]	validation_0-rmse:109.93103
# [727]	validation_0-rmse:109.93880
# [728]	validation_0-rmse:109.88122
# [729]	validation_0-rmse:109.92405
# [730]	validation_0-rmse:109.92184
# [731]	validation_0-rmse:109.92696
# [732]	validation_0-rmse:109.91231
# [733]	validation_0-rmse:109.89459
# [734]	validation_0-rmse:109.91219
# [735]	validation_0-rmse:109.94687
# [736]	validation_0-rmse:109.97860
# [737]	validation_0-rmse:109.99954
# [738]	validation_0-rmse:110.03871
# [739]	validation_0-rmse:110.04933
# [740]	validation_0-rmse:110.04512
# [741]	validation_0-rmse:110.03611
# [742]	validation_0-rmse:110.04024
# [743]	validation_0-rmse:110.01079
# [744]	validation_0-rmse:110.02193
# [745]	validation_0-rmse:110.02197
# [746]	validation_0-rmse:110.06408
# [747]	validation_0-rmse:110.03390
# [748]	validation_0-rmse:110.05965
# [749]	validation_0-rmse:110.07584
# [750]	validation_0-rmse:110.09483
# [751]	validation_0-rmse:110.10850
# [752]	validation_0-rmse:110.10682
# [753]	validation_0-rmse:110.09655
# [754]	validation_0-rmse:110.10003
# [755]	validation_0-rmse:110.09238
# [756]	validation_0-rmse:110.08587
# [757]	validation_0-rmse:110.05906
# [758]	validation_0-rmse:110.06523
# [759]	validation_0-rmse:110.06578
# [760]	validation_0-rmse:110.03065
# [761]	validation_0-rmse:110.03410
# [762]	validation_0-rmse:110.00751
# [763]	validation_0-rmse:110.01015
# [764]	validation_0-rmse:110.11096
# [765]	validation_0-rmse:110.10274
# [766]	validation_0-rmse:110.08367
# [767]	validation_0-rmse:110.10351
# [768]	validation_0-rmse:110.11732
# [769]	validation_0-rmse:110.12329
# [770]	validation_0-rmse:110.12832
# [771]	validation_0-rmse:110.13296
# [772]	validation_0-rmse:110.17534
# [773]	validation_0-rmse:110.18890
# [774]	validation_0-rmse:110.20055
# [775]	validation_0-rmse:110.19464
# [776]	validation_0-rmse:110.20186
# [777]	validation_0-rmse:110.17692
# [778]	validation_0-rmse:110.18234
# [779]	validation_0-rmse:110.18772
# [780]	validation_0-rmse:110.19664
# [781]	validation_0-rmse:110.22955
# [782]	validation_0-rmse:110.27501
# [783]	validation_0-rmse:110.26732
# [784]	validation_0-rmse:110.24525
# [785]	validation_0-rmse:110.25127
# [786]	validation_0-rmse:110.24332
# [787]	validation_0-rmse:110.21775
# [788]	validation_0-rmse:110.22273
# [789]	validation_0-rmse:110.19171
# [790]	validation_0-rmse:110.19491
# [791]	validation_0-rmse:110.21497
# [792]	validation_0-rmse:110.21774
# [793]	validation_0-rmse:110.21484
# [794]	validation_0-rmse:110.20118
# [795]	validation_0-rmse:110.19508
# [796]	validation_0-rmse:110.21519
# [797]	validation_0-rmse:110.21777
# [798]	validation_0-rmse:110.28295
# [799]	validation_0-rmse:110.29922
# [800]	validation_0-rmse:110.29193
# [801]	validation_0-rmse:110.28411
# [802]	validation_0-rmse:110.30016
# [803]	validation_0-rmse:110.30213
# [804]	validation_0-rmse:110.32075
# [805]	validation_0-rmse:110.30729
# [806]	validation_0-rmse:110.38927
# [807]	validation_0-rmse:110.38728
# [808]	validation_0-rmse:110.39499
# [809]	validation_0-rmse:110.40429
# [810]	validation_0-rmse:110.40645
# [811]	validation_0-rmse:110.42379
# [812]	validation_0-rmse:110.42491
# [813]	validation_0-rmse:110.41554
# [814]	validation_0-rmse:110.43617
# [815]	validation_0-rmse:110.42824
# [816]	validation_0-rmse:110.42493
# [817]	validation_0-rmse:110.43373
# [818]	validation_0-rmse:110.42553
# [819]	validation_0-rmse:110.43197
# [820]	validation_0-rmse:110.45882
# [821]	validation_0-rmse:110.44927
# [822]	validation_0-rmse:110.39784
# [823]	validation_0-rmse:110.35868
# [824]	validation_0-rmse:110.37334
# [825]	validation_0-rmse:110.38674
# [826]	validation_0-rmse:110.42027
# [827]	validation_0-rmse:110.41052
# [828]	validation_0-rmse:110.40153
# [829]	validation_0-rmse:110.52551
# [830]	validation_0-rmse:110.52725
# [831]	validation_0-rmse:110.51666
# [832]	validation_0-rmse:110.50848
# [833]	validation_0-rmse:110.51579
# [834]	validation_0-rmse:110.52025
# [835]	validation_0-rmse:110.53285
# [836]	validation_0-rmse:110.53303
# [837]	validation_0-rmse:110.52761
# [838]	validation_0-rmse:110.52709
# [839]	validation_0-rmse:110.54674
# [840]	validation_0-rmse:110.56729
# [841]	validation_0-rmse:110.56450
# [842]	validation_0-rmse:110.58264
# [843]	validation_0-rmse:110.57448
# [844]	validation_0-rmse:110.57452
# [845]	validation_0-rmse:110.57083
# [846]	validation_0-rmse:110.55975
# [847]	validation_0-rmse:110.56246
# [848]	validation_0-rmse:110.58010
# [849]	validation_0-rmse:110.58913
# [850]	validation_0-rmse:110.59159
# [851]	validation_0-rmse:110.58652
# [852]	validation_0-rmse:110.58656
# [853]	validation_0-rmse:110.65890
# [854]	validation_0-rmse:110.67662
# [855]	validation_0-rmse:110.65463
# [856]	validation_0-rmse:110.69981
# [857]	validation_0-rmse:110.70405
# [858]	validation_0-rmse:110.69790
# [859]	validation_0-rmse:110.72117
# [860]	validation_0-rmse:110.75865
# [861]	validation_0-rmse:110.74289
# [862]	validation_0-rmse:110.73884
# [863]	validation_0-rmse:110.78655
# [864]	validation_0-rmse:110.80283
# [865]	validation_0-rmse:110.81436
# [866]	validation_0-rmse:110.80940
# [867]	validation_0-rmse:110.86059
# [868]	validation_0-rmse:110.86219
# [869]	validation_0-rmse:110.86531
# [870]	validation_0-rmse:110.87462
# [871]	validation_0-rmse:110.85379
# [872]	validation_0-rmse:110.83511
# [873]	validation_0-rmse:110.83325
# [874]	validation_0-rmse:110.86559
# [875]	validation_0-rmse:110.85357
# [876]	validation_0-rmse:110.77484
# [877]	validation_0-rmse:110.79953
# [878]	validation_0-rmse:110.80660
# [879]	validation_0-rmse:110.81842
# [880]	validation_0-rmse:110.81909
# [881]	validation_0-rmse:110.85507
# [882]	validation_0-rmse:110.85264
# [883]	validation_0-rmse:110.83915
# [884]	validation_0-rmse:110.82194
# [885]	validation_0-rmse:110.85230
# [886]	validation_0-rmse:110.89019
# [887]	validation_0-rmse:110.89973
# [888]	validation_0-rmse:110.89195
# [889]	validation_0-rmse:110.87964
# [890]	validation_0-rmse:110.85968
# [891]	validation_0-rmse:110.85774
# [892]	validation_0-rmse:110.89120
# [893]	validation_0-rmse:110.92836
# [894]	validation_0-rmse:110.93628
# [895]	validation_0-rmse:110.93112
# [896]	validation_0-rmse:110.93300
# [897]	validation_0-rmse:110.95012
# [898]	validation_0-rmse:110.93919
# [899]	validation_0-rmse:110.98014
# [900]	validation_0-rmse:110.97525
# [901]	validation_0-rmse:110.99571
# [902]	validation_0-rmse:111.00302
# [903]	validation_0-rmse:111.00418
# [904]	validation_0-rmse:110.98023
# [905]	validation_0-rmse:111.01586
# [906]	validation_0-rmse:111.00198
# [907]	validation_0-rmse:111.00767
# [908]	validation_0-rmse:111.00269
# [909]	validation_0-rmse:111.00474
# [910]	validation_0-rmse:111.00969
# [911]	validation_0-rmse:110.98358
# [912]	validation_0-rmse:110.99524
# [913]	validation_0-rmse:110.98828
# [914]	validation_0-rmse:110.99487
# [915]	validation_0-rmse:111.00921
# [916]	validation_0-rmse:111.03371
# [917]	validation_0-rmse:111.01770
# [918]	validation_0-rmse:111.04154
# [919]	validation_0-rmse:111.05226
# [920]	validation_0-rmse:111.06452
# [921]	validation_0-rmse:111.05229
# [922]	validation_0-rmse:111.07396
# [923]	validation_0-rmse:111.07060
# [924]	validation_0-rmse:111.07179
# [925]	validation_0-rmse:111.08151
# [926]	validation_0-rmse:111.06901
# [927]	validation_0-rmse:111.06951
# [928]	validation_0-rmse:111.07368
# [929]	validation_0-rmse:111.09694
# [930]	validation_0-rmse:111.08556
# [931]	validation_0-rmse:111.09971
# [932]	validation_0-rmse:111.07456
# [933]	validation_0-rmse:111.08609
# [934]	validation_0-rmse:111.07356
# [935]	validation_0-rmse:111.05458
# [936]	validation_0-rmse:111.09757
# [937]	validation_0-rmse:111.09218
# [938]	validation_0-rmse:111.12237
# [939]	validation_0-rmse:111.09083
# [940]	validation_0-rmse:111.10315
# [941]	validation_0-rmse:111.10180
# [942]	validation_0-rmse:111.09848
# [943]	validation_0-rmse:111.09874
# [944]	validation_0-rmse:111.10817
# [945]	validation_0-rmse:111.11233
# [946]	validation_0-rmse:111.11959
# [947]	validation_0-rmse:111.12907
# [948]	validation_0-rmse:111.14445
# [949]	validation_0-rmse:111.14924
# [950]	validation_0-rmse:111.14379
# [951]	validation_0-rmse:111.13684
# [952]	validation_0-rmse:111.13942
# [953]	validation_0-rmse:111.14297
# [954]	validation_0-rmse:111.14029
# [955]	validation_0-rmse:111.14656
# [956]	validation_0-rmse:111.15952
# [957]	validation_0-rmse:111.16575
# [958]	validation_0-rmse:111.11391
# [959]	validation_0-rmse:111.11569
# [960]	validation_0-rmse:111.11126
# [961]	validation_0-rmse:111.12965
# [962]	validation_0-rmse:111.14785
# [963]	validation_0-rmse:111.15714
# [964]	validation_0-rmse:111.14327
# [965]	validation_0-rmse:111.15889
# [966]	validation_0-rmse:111.14941
# [967]	validation_0-rmse:111.14928
# [968]	validation_0-rmse:111.14253
# [969]	validation_0-rmse:111.14511
# [970]	validation_0-rmse:111.16011
# [971]	validation_0-rmse:111.22018
# [972]	validation_0-rmse:111.27136
# [973]	validation_0-rmse:111.36304
# [974]	validation_0-rmse:111.36601
# [975]	validation_0-rmse:111.35518
# [976]	validation_0-rmse:111.34403
# [977]	validation_0-rmse:111.37221
# [978]	validation_0-rmse:111.38638
# [979]	validation_0-rmse:111.40450
# [980]	validation_0-rmse:111.38272
# [981]	validation_0-rmse:111.36383
# [982]	validation_0-rmse:111.37813
# [983]	validation_0-rmse:111.39967
# [984]	validation_0-rmse:111.38964
# [985]	validation_0-rmse:111.39759
# [986]	validation_0-rmse:111.40164
# [987]	validation_0-rmse:111.39146
# [988]	validation_0-rmse:111.38406
# [989]	validation_0-rmse:111.38499
# [990]	validation_0-rmse:111.40623
# [991]	validation_0-rmse:111.42081
# [992]	validation_0-rmse:111.38887
# [993]	validation_0-rmse:111.38931
# [994]	validation_0-rmse:111.39426
# [995]	validation_0-rmse:111.35493
# [996]	validation_0-rmse:111.34217
# [997]	validation_0-rmse:111.35268
# [998]	validation_0-rmse:111.34177
# [999]	validation_0-rmse:111.37317
#
# --- Model Performance ---
# Root Mean Squared Error (RMSE): 111.37 L/hr
# Mean Absolute Error (MAE): 88.20 L/hr
#
# Generating forecast for the next 24 hours...
# Forecast (First 5 hours):
# 2024-12-31 00:00:00    2074.040039
# 2024-12-31 01:00:00    2275.867188
# 2024-12-31 02:00:00    2360.555664
# 2024-12-31 03:00:00    2397.652832
# 2024-12-31 04:00:00    2325.944336
# Freq: h, Name: Forecast_L, dtype: float32
